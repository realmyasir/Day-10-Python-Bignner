# %%
# alphabet='abcdefghijklmnopqrstuvwxyz'

# %%
input_text='mudasar'

# %%
output=''
for char in input_text:
    alpha_index=alphabet.find (char)
    output = output + alphabet[alpha_index+2]
    print(output)
# Out:
# o
# ow
# owf
# owfc
# owfcu
# owfcuc
# owfcuct

# %%
10%8
# Out:
# 2

# %%
# def shift_amount(i):
#     return i%26

# %%
output_1 =''
for char in input_text:
    alpha_index = alphabet.find(char)
    output_1=output_1 + alphabet[shift_amount(alpha_index+30)]
print (output_1)
# Out:
# qyhewwev

# %%
  def encrypt(text,required_shift):
        out_string=''
        text=text.lower()
        for char in text:
            if char not in alphabet:
                out_string = out_string + char
            else:
                alpha_index = alphabet.find(char)
                out_string=out_string+alphabet[shift_amount(alpha_index + required_shift)]
        return out_string

# %%
new_string='Yasir Abbas'
shift = encrypt(new_string,5)

# %%
shift
# Out:
# 'dfxnw fggfx'

# %%
alphabet='abcdefghijklmnopqrstuvwxyz'
def shift_amount(i):
    return i%26

def encrypt(text,required):
    out=''
    text=text.lower()
    for char in text:
        if char not in alphabet:
            out=out+char
        else:
            alpha_index=alphabet.find(char)
            out=out+alphabet[shift_amount(alpha_index + required)]
    return out
new='ghijklmnop'
shift=encrypt(new,5+2)
shift
# Out:
# 'fhzpy hiihz'

# %%
new1='''When analyzing the efficiency of Python code, it's essential to consider both time and space complexity. Understanding the Big O notation helps programmers make informed decisions about algorithm selection, especially when dealing with large datasets or resource-constrained environments.'''
encrypt_1=encrypt(new1,5)
print(encrypt_1)
# Out:
# bmjs fsfqdensl ymj jkknhnjshd tk udymts htij, ny'x jxxjsynfq yt htsxnijw gtym ynrj fsi xufhj htruqjcnyd. zsijwxyfsinsl ymj gnl t styfynts mjqux uwtlwfrrjwx rfpj nsktwrji ijhnxntsx fgtzy fqltwnymr xjqjhynts, jxujhnfqqd bmjs ijfqnsl bnym qfwlj ifyfxjyx tw wjxtzwhj-htsxywfnsji jsanwtsrjsyx.
